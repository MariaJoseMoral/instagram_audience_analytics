# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt 

pd.set_option('display.max_columns', None)

# %%
with open("campa.csv", "r", encoding="utf-8", errors="replace") as f:
    for i, line in enumerate(f, start=1):
        if 28 <= i <= 36:
            print(i, repr(line))
# Out:
# 28 'cultura@cardedeu.cat;;Ajuntament de Cardedeu\n'
# 29 'daphmalherbe@gmail.com;;El Garitu\n'
# 30 'dinamitzacio@casadelrellotge.net;;Centre Cívic Casa del Rellotge / Sala Pepita Casanellas / Sala Maremar\n'
# 31 'direccio@sedeta.cat;;Centre Cívic La Sedeta\n'
# 32 "eduard.garcia@secretariat.cat;;Secretariat d'Entitats de Sants, Hostafrancs i la Bordeta\n"
# 33 'fenix@salafenix.com;;Sala Fènix\n'
# 34 'gestio@canclariana.cat;;Centre Cívic Can Clariana Cultural\n'
# 35 'gm@suikapro.com;Marsal;Gabriela\n'
# 36 'info@bipolart.org;;Associació Bipol.art\n'

# %%
df = pd.read_csv(
    "4.csv",
    sep=",",
    encoding="utf-8"
)

df.head()



df.columns = df.columns.str.lower()

df['apellidos'] = df["apellidos"].fillna('unknown')

df.info()

df.sample()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   email      285 non-null    object
#  1   apellidos  285 non-null    object
#  2   nombre     285 non-null    object
# dtypes: object(3)
# memory usage: 6.8+ KB
#                            email           apellidos nombre
# 54  barandi.produccion@gmail.com  Santacana Apaolaza  Iñigo

# %%
df.to_csv('clicks_artistas_clean.csv')
